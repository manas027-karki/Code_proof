# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns


import pickle


from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression 
from sklearn.metrics import classification_report, accuracy_score
from sklearn.model_selection import GridSearchCV
from sklearn.utils import resample

import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
df = pd.read_excel("updated_dataset.xlsx")

# %%
df[df["risk_level"] == "NONE"]
# Out:
#                                                    value risk_level
# 6000   for i in range(10): print(i)\ny=x*2\nconsole.l...       NONE
# 6001   y=x*2\nfor i in range(10): print(i)\ndef add(a...       NONE
# 6002   console.log('Hello')\ny=x*2\nfor i in range(10...       NONE
# 6003   x=5\nconsole.log('Hello')\nconsole.log('Hello'...       NONE
# 6004   console.log('Hello')\nx=5\nconsole.log('Hello'...       NONE
# ...                                                  ...        ...
# 11052  5cx8ttN2pqkQTt2rnLIaMDspLhzD87OZ.pUFGnB0Te8OYHYcc       NONE
# 11053  NyeS5c75YYL1r9GZmDs9A8zxm8z4ozT1.fIeaweBaukTWVRkC       NONE
# 11054  BgqmQMO1D9QyoxeWMl535BjRzJkQSa43.JCNtiq32R5kiFTu2       NONE
# 11055  5syKm0X17Fj2PAPOwNnGgNetG2ygmql4.RgXXam1sfKPNAztC       NONE
# 11056  cMYZggM9KB2HnP7uZV91kvciEImxUOP7.ZvvmSUqeRbqssNFD       NONE
#
# [4162 rows x 2 columns]

# %%
df.head()
# Out:
#                                         value risk_level
# 0     py\ntoken='sk-66cuSzxVxek6xB0MFYC7kkvp'       HIGH
# 1    py\nsecret='sk-FCclDaiiywyDzTEDqxWf6qRe'       HIGH
# 2  py\npassword='sk-u6yCnorTTLWGIXfMr2Wl66Gx'       HIGH
# 3   py\nAPI_KEY='sk-IUbQgN1aGYJ5LaKnxVFUzGTF'       HIGH
# 4  py\npassword='sk-59BqgMKaUb3G67EiDXaY45gA'       HIGH

# %%
df_cpy = df.copy()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11057 entries, 0 to 11056
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   value       11057 non-null  object
#  1   risk_level  11057 non-null  object
# dtypes: object(2)
# memory usage: 172.9+ KB

# %%
df.isnull().sum()
# Out:
# value         0
# risk_level    0
# dtype: int64

# %%
df['risk_level'].value_counts()
# Out:
# risk_level
# NONE        4162
# HIGH        3517
# CRITICAL    3378
# Name: count, dtype: int64

# %%
df.head()
# Out:
#                                         value risk_level
# 0     py\ntoken='sk-66cuSzxVxek6xB0MFYC7kkvp'       HIGH
# 1    py\nsecret='sk-FCclDaiiywyDzTEDqxWf6qRe'       HIGH
# 2  py\npassword='sk-u6yCnorTTLWGIXfMr2Wl66Gx'       HIGH
# 3   py\nAPI_KEY='sk-IUbQgN1aGYJ5LaKnxVFUzGTF'       HIGH
# 4  py\npassword='sk-59BqgMKaUb3G67EiDXaY45gA'       HIGH

# %%
df.isnull().sum()
# Out:
# value         0
# risk_level    0
# dtype: int64

# %%
df['risk_level'].value_counts()
# Out:
# risk_level
# NONE        4162
# HIGH        3517
# CRITICAL    3378
# Name: count, dtype: int64

# %%
df['risk_level'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['risk_level']  = df['risk_level'].str.lower()

# %%
df['risk_level'] = df['risk_level'].map({'high' : 1, 'critical' : 2, 'none' : 0})

# %%
X = df['value']
Y = df['risk_level']

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size = 0.25, random_state = 42)

# %%
vectorizer = TfidfVectorizer( analyzer='char', ngram_range=(3,6))

# %%
X_train_vec = vectorizer.fit_transform(X_train)
X_test_vec = vectorizer.transform(X_test)

# %%
model1 = LogisticRegression()
params = {'penalty' : ['l1', 'l2', 'elasticnet', None],
         'dual' : [True, False],
         'fit_intercept' : [True, False],
         'solver' : ['lbfgs', 'liblinear', 'newton-cg', 'newton-cholesky', 'sag', 'saga'],
         'multi_class' : ['auto', 'ovr', 'multinomial']
         }

# %%
grid = GridSearchCV(model1, params, n_jobs=-1)

# %%
grid.fit(X_train_vec, Y_train)
# Out:
# GridSearchCV(estimator=LogisticRegression(), n_jobs=-1,
#              param_grid={'dual': [True, False], 'fit_intercept': [True, False],
#                          'multi_class': ['auto', 'ovr', 'multinomial'],
#                          'penalty': ['l1', 'l2', 'elasticnet', None],
#                          'solver': ['lbfgs', 'liblinear', 'newton-cg',
#                                     'newton-cholesky', 'sag', 'saga']})

# %%
grid.score(X_train_vec, Y_train)
# Out:
# 0.9476603955619874

# %%
grid.score(X_test_vec, Y_test)
# Out:
# 0.9464737793851717

# %%
text = 'postgresPass_123abc'
textv = vectorizer.transform([text]).toarray()
result = grid.predict(textv)
if result[0] == 1:
    print("High Risk")
elif result[0] == 2:
    print("Critical")
elif result[0] == 0:
    print("No Risk")
# Out:
# High Risk

# %%
from sklearn.metrics import confusion_matrix
y_pred = grid.predict(X_test_vec)
cm = confusion_matrix(Y_test, y_pred)
plt.figure()
sns.heatmap(cm, 
            annot=True, 
            fmt='d', 
            xticklabels=[0,1,2], 
            yticklabels=[0,1,2])

plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# %%
with open("model.pkl", "wb") as f:
    pickle.dump(grid, f)

with open("vectorizer.pkl", "wb") as f:
    pickle.dump(vectorizer, f)
